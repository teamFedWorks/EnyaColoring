# %%
# %run youtube_urls_csv_update.py
# Out:
# ✅ Fetched 34 rows from online sheet
# 📂 Loaded 35 rows from local master CSV
# ⚠️ Ignored 34 duplicate URLs
# ✅ Updated and saved master sheet: 35 rows

# %%
# %run youtube_urls_batch_run.py
# Out:
# ⚙️ Run in automated mode? [y/N]:  N
# 📨 Enable email notification on each video? [y/N]:  Y
# 📁 Use default master CSV path 'first_youtube_urls.csv'? [Y/n]:  Y
# 🎯 Video URL: https://www.youtube.com/watch?v=e7os6Ru_CuU
# ▶️ Process this video? https://www.youtube.com/watch?v=e7os6Ru_CuU [y/N]:  Y
# [youtube] Extracting URL: https://www.youtube.com/watch?v=e7os6Ru_CuU
# [youtube] e7os6Ru_CuU: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one. To silence this warning, you can use  --extractor-args "youtube:player_client=default"
# [youtube] e7os6Ru_CuU: Downloading android sdkless player API JSON
# [youtube] e7os6Ru_CuU: Downloading web safari player API JSON
# ...

# %%
import torch, gc
torch.cuda.synchronize()
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
!

# %%
import pandas as pd

csv_path = "master_sheet_youtube_urls.csv"  # Replace with your actual path
df = pd.read_csv(csv_path)

print("🧾 Column Names:")
for col in df.columns:
    print(f"- {col}")
# Out:
# 🧾 Column Names:
# - YouTube URL
# - face_upscale
# - background_upscale
# - background_upscale_value
# - unet
# - crop_video
# - start_time (00:00:00)
# - end_time (01:22:33)
# - Executed
# - Start Time
# - End Time
# - Remarks
# - Input Path

# %%
# %run main_batch.py
# Out:
# ✅ Fetched 31 rows from online sheet
# 📂 Loaded 31 rows from local master CSV
# ⚠️ Ignored 31 duplicate URLs from online sheet
# ✅ Updated and deduplicated master sheet: 31 rows
#
# 🎯 Video URL: https://www.youtube.com/watch?v=lyrTKe-WJhM
# ➡️ Run pipeline for this video? [y/n]:  n
# 🎯 Video URL: https://www.youtube.com/watch?v=L9EOHv93enE
# ➡️ Run pipeline for this video? [y/n]:  y
# [youtube] Extracting URL: https://www.youtube.com/watch?v=L9EOHv93enE
# [youtube] L9EOHv93enE: Downloading webpage
# [youtube] L9EOHv93enE: Downloading tv client config
# [youtube] L9EOHv93enE: Downloading player 14397202-main
# [youtube] L9EOHv93enE: Downloading tv player API JSON
# [youtube] L9EOHv93enE: Downloading ios player API JSON
# WARNING: [youtube] L9EOHv93enE: Some tv client https formats have been skipped as they are DRM protected. The current session may have an experiment that applies DRM to all videos on the tv client. See  https://github.com/yt-dlp/yt-dlp/issues/12563  for more details.
# ...
